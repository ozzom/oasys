# %%
import numpy as np

data = np.random.randint(-100, 100,50).cumsum()
data
# Out:
# array([ -43,   32,  -10,   64,  -14,  -96,  -59, -156,  -99,  -42,  -80,
#         -15,    1,   15,   83,   44,  113,  102,  131,  118,   96,    5,
#          87,   31,  122,   82,   88,   -5,   28,   26,  -22,   42,  106,
#         120,  207,  281,  274,  370,  457,  357,  308,  337,  400,  363,
#         455,  443,  446,  393,  413,  347])

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
matplotlib.rcParams['font.family'] ='NanumGothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

plt.plot([-4, -3, -2, -1, 0, 1, 2, 3, 4], [12, 32, -4, 0, 5, 2, 19, 9, 3])
plt.xlabel('x축')
plt.ylabel('y축')
plt.title('제목')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
