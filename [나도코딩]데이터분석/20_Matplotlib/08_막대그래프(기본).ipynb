# %% [markdown]
# # 8. 막대그래프(기본)
#
# ### x축 : 레이블, Y축 : Value

# %%
import matplotlib.pyplot as plt 
import matplotlib

matplotlib.rcParams['font.family']= 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
lable = ['강백호','서태웅','정대만',]  # 이름 
values = [190, 187, 184]              # 키

# %%
plt.bar(lable, values, color = 'r')
# Out:
# <BarContainer object of 3 artists>

# %%
lable = ['강백호','서태웅','정대만',]  # 이름 
values = [190, 187, 184]              # 키      
colors = ['r', 'g' ,'b']

plt.bar(lable, values, color = colors, alpha = 0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
lable = ['강백호','서태웅','정대만',]  # 이름 
values = [190, 187, 184]              # 키      
colors = ['r', 'g' ,'b']

plt.bar(lable, values)

plt.ylim(175, 195)   # ylim으로 Y축 범위를 조정함.
# Out:
# (175.0, 195.0)

# %%
plt.bar(lable, values, width = 0.3)  # width =  bar의 폭 조정 
plt.xticks(rotation=45)   # X축 이름 데이터 각도를 45도로 설정
plt.yticks(rotation=45)   # Y축 이름 데이터 각도를 45도로 설정
# Out:
# (array([  0.,  50., 100., 150., 200.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
ticks = ['1번', '2번', '3번']
lable = ['강백호','서태웅','정대만',]  # 이름 
values = [190, 187, 184]              # 키   

plt.bar(lable, values, width = 0.5)
plt.ylim(180, 195)
plt.xticks(lable, ticks, rotation=45)            # 레이블을 바꿔서 표현할 때..
# Out:
# ([<matplotlib.axis.XTick at 0x1df8a91b2b0>,
# ...
#  [Text(0.0, 0, '1번'), Text(1.0, 0, '2번'), Text(2.0, 0, '3번')])
